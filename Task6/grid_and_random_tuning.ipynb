# %% [markdown]
# <a href="https://colab.research.google.com/github/prpawan03/marvel-lvl2/blob/main/Task6/grid_and_random_tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

from sklearn import ensemble,metrics,model_selection

# %%
df = pd.read_csv("train.csv")
X = df.drop("price_range", axis = 1).values
y = df.price_range.values

# %%
classifier = ensemble.RandomForestClassifier(n_jobs = -1)
parametergrid = {
    "n_estimators": [100,200,300,400,500,1000],
    "max_depth": [1,3,4,5,8,10],
    "criterion" :["gini","entropy"],
}

# %%
model = model_selection.GridSearchCV(
    estimator = classifier,
    param_grid=parametergrid,
    scoring = "accuracy",
    verbose=10,
    n_jobs =1,
    cv = 5,
)
model.fit(X,y)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV 1/5; 1/72] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 1/5; 1/72] END criterion=gini, max_depth=1, n_estimators=100;, score=0.573 total time=   0.3s
# [CV 2/5; 1/72] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 2/5; 1/72] END criterion=gini, max_depth=1, n_estimators=100;, score=0.578 total time=   0.3s
# [CV 3/5; 1/72] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 3/5; 1/72] END criterion=gini, max_depth=1, n_estimators=100;, score=0.588 total time=   0.3s
# [CV 4/5; 1/72] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 4/5; 1/72] END criterion=gini, max_depth=1, n_estimators=100;, score=0.627 total time=   0.3s
# [CV 5/5; 1/72] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 5/5; 1/72] END criterion=gini, max_depth=1, n_estimators=100;, score=0.580 total time=   0.3s
# ...

# %%
print(model.best_score_)
print(model.best_estimator_.get_params)
# Out:
# 0.8870000000000001
# <bound method BaseEstimator.get_params of RandomForestClassifier(criterion='entropy', max_depth=10, n_estimators=500,
#                        n_jobs=-1)>

# %%
classifier = ensemble.RandomForestClassifier(n_jobs = -1)
parametergrid = {
    "n_estimators": np.arange(0,1400,100),
    "max_depth": np.arange(1,15),
    "criterion" :["gini","entropy"],
}
model = model_selection.RandomizedSearchCV(
    estimator = classifier,
    param_distributions=parametergrid,
    scoring = "accuracy",
    n_iter=10,
    verbose=10,
    n_jobs =1,
    cv = 5,
)
model.fit(X,y)
print(model.best_score_)
print(model.best_estimator_.get_params)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5; 1/10] START criterion=gini, max_depth=13, n_estimators=1100............
# [CV 1/5; 1/10] END criterion=gini, max_depth=13, n_estimators=1100;, score=0.887 total time=   4.9s
# [CV 2/5; 1/10] START criterion=gini, max_depth=13, n_estimators=1100............
# [CV 2/5; 1/10] END criterion=gini, max_depth=13, n_estimators=1100;, score=0.882 total time=   4.8s
# [CV 3/5; 1/10] START criterion=gini, max_depth=13, n_estimators=1100............
# [CV 3/5; 1/10] END criterion=gini, max_depth=13, n_estimators=1100;, score=0.897 total time=   5.7s
# [CV 4/5; 1/10] START criterion=gini, max_depth=13, n_estimators=1100............
# [CV 4/5; 1/10] END criterion=gini, max_depth=13, n_estimators=1100;, score=0.880 total time=   4.8s
# [CV 5/5; 1/10] START criterion=gini, max_depth=13, n_estimators=1100............
# [CV 5/5; 1/10] END criterion=gini, max_depth=13, n_estimators=1100;, score=0.865 total time=   5.6s
# ...

# %%
print(model.best_score_)
print(model.best_estimator_.get_params)
# Out:
# 0.8875
# <bound method BaseEstimator.get_params of RandomForestClassifier(criterion='entropy', max_depth=14, n_estimators=1300,
#                        n_jobs=-1)>
