# %% [markdown]
# <a href="https://colab.research.google.com/github/prpawan03/marvel-lvl2/blob/main/task5/random_forrest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/all_stocks_5yr.csv")
df.shape
df
# Out:
#               date   open   high    low  close    volume Name
# 0       2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1       2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2       2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3       2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4       2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL
# ...            ...    ...    ...    ...    ...       ...  ...
# 619035  2018-02-01  76.84  78.27  76.69  77.82   2982259  ZTS
# 619036  2018-02-02  77.53  78.12  76.73  76.78   2595187  ZTS
# 619037  2018-02-05  76.64  76.92  73.18  73.83   2962031  ZTS
# 619038  2018-02-06  72.74  74.56  72.13  73.27   4924323  ZTS
# 619039  2018-02-07  72.70  75.00  72.69  73.86   4534912  ZTS
#
# [619040 rows x 7 columns]

# %%
df.plot(x="date",y="close" )
# Out:
# <Axes: xlabel='date'>

# %%
df = pd.read_csv("/content/NVDA_data.csv")
df.shape
df
# Out:
#             date     open      high     low   close    volume  Name
# 0     2013-02-08   12.370   12.4699   12.29   12.37   7677336  NVDA
# 1     2013-02-11   12.470   12.6350   12.35   12.51  10207599  NVDA
# 2     2013-02-12   12.395   12.5650   12.38   12.43   6945065  NVDA
# 3     2013-02-13   12.440   12.6650   12.33   12.37  21322573  NVDA
# 4     2013-02-14   12.200   12.7400   12.05   12.73  22049335  NVDA
# ...          ...      ...       ...     ...     ...       ...   ...
# 1254  2018-02-01  238.520  246.9000  238.06  240.50  12980572  NVDA
# 1255  2018-02-02  237.000  237.9700  231.17  233.52  17961555  NVDA
# 1256  2018-02-05  227.000  233.2300  205.00  213.70  29130140  NVDA
# 1257  2018-02-06  204.400  225.7000  204.00  225.58  27870031  NVDA
# 1258  2018-02-07  229.580  234.9700  226.70  228.80  20073316  NVDA
#
# [1259 rows x 7 columns]

# %%
df.plot(x="date",y="close" )
# Out:
# <Axes: xlabel='date'>

# %%
model = RandomForestRegressor()

X = df[['open','high','low','volume']]
X = X[:int(len(df)-1)]
y = df['close']
y = y[:int(len(df)-1)]
model.fit(X,y)
RandomForestRegressor()
# Out:
# RandomForestRegressor()

# %%
predictions = model.predict(X)
print('The model score is :', model.score(X,y))
# Out:
# The model score is : 0.9999482902976348

# %%
newx = df[['open','high','low','volume']].tail(1)
prediction = model.predict(newx)
print("the model predicts the last day's stock price to be:",prediction)
print("the actual value is :",df[['close']].tail(1).values[0][0])
# Out:
# the model predicts the last day's stock price to be: [231.1266]
# the actual value is : 228.8
